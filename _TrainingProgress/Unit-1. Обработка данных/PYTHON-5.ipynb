# %%
import pandas as pd
from IPython.core.display import display

data = pd.Series(["Январь", "Февраль", "Март", "Апрель"],
                 index = ['Первый', "Второй", "Третий", "Четвёртый"])
display(data)
# Out:
# Первый        Январь
# Второй       Февраль
# Третий          Март
# Четвёртый     Апрель
# dtype: object

# %%
import pandas as pd

data = pd.Series(list(range(10, 1001)))
display(data)


print(data.loc[10] + data.loc[23] - data.loc[245] + data.iloc[122])
# Out:
# 0        10
# 1        11
# 2        12
# 3        13
# 4        14
#        ...
# 986     996
# 987     997
# 988     998
# 989     999
# 990    1000
# Length: 991, dtype: int64
# -70

# %%
import pandas as pd


football = pd.read_csv('./data_sf.xls')
display(football.info())
display(football['Club'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12897 entries, 0 to 12896
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       12897 non-null  int64
#  1   Name             12897 non-null  object
#  2   Age              12897 non-null  int64
#  3   Nationality      12897 non-null  object
#  4   Club             12897 non-null  object
#  5   Value            12897 non-null  int64
#  6   Wage             12897 non-null  int64
#  7   Position         12897 non-null  object
#  8   Crossing         12897 non-null  int64
#  9   Finishing        12897 non-null  int64
#  10  HeadingAccuracy  12897 non-null  int64
#  11  ShortPassing     12897 non-null  int64
#  12  Volleys          12897 non-null  int64
#  13  Dribbling        12897 non-null  int64
#  14  Curve            12897 non-null  int64
#  15  FKAccuracy       12897 non-null  int64
#  16  LongPassing      12897 non-null  int64
# ...

# %%
import pandas as pd

football = pd.read_csv('./data_sf.xls')

# display(football.describe())

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(football.describe())

# football.info()
# display(football.describe(include = ['object']))


display(
    round(football.Age.describe()['mean']),
    football.Age.describe()['min'],
    football.Wage.describe()['max'],
    football.Wage.describe()['50%'],
    football.Penalties.describe()['min'],
    football.ShortPassing.describe()['25%'],

    football.Nationality.describe()['top'],
    football.Nationality.describe()['freq'],
    football.Club.describe()['unique'],
    football.describe(include = ['object'])['Position']['freq'],
    football.Age.describe()['max']
)
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
import pandas as pd

football = pd.read_csv('./data_sf.xls')

display(
    round(football.Age.mean()),
    football.Composure.count(),
    round(football.ShortPassing.std(), 2),
    football.Wage.sum(),
    football.Value.min(),
)
# Out:
# 25
# 12897
# 14.74
# 96954000
# 0

# %%
import pandas as pd
football = pd.read_csv('./data_sf.xls')

display(
    football[football.Age > football.Age.mean()],

    football[(football.Age < football.Age.mean())|
        (football.Club == 'FC Barcelona')],

)
# Out:
#        Unnamed: 0               Name  Age   Nationality  \
# 0               0           L. Messi   31     Argentina
# 1               1  Cristiano Ronaldo   33      Portugal
# 2               2          Neymar Jr   26        Brazil
# 3               3             De Gea   27         Spain
# 4               4       K. De Bruyne   27       Belgium
# ...           ...                ...  ...           ...
# 12746       12975      Teng Shangkun   27      China PR
# 12749       12978         M. Mansour   26  Saudi Arabia
# 12767       12996          Sun Qibin   26      China PR
# 12861       13090        Y. Uchimura   33         Japan
# 12873       13102      K. Pilkington   44       England
#
#                              Club      Value    Wage Position  Crossing  \
# 0                    FC Barcelona  110500000  565000       RF        84
# 1                        Juventus   77000000  405000       ST        84
# 2             Paris Saint-Germain  118500000  290000       LW        79
# ...

# %%
import pandas as pd

football = pd.read_csv('./data_sf.csv')

display(
    # Какова средняя скорость (SprintSpeed) футболистов, зарплата (Wage) которых выше среднего?
    # Ответ округлите до сотых.
    round(football[football.Wage > football.Wage.mean()].SprintSpeed.mean(), 2),


    # Какова средняя скорость (SprintSpeed) футболистов, зарплата (Wage) которых ниже среднего?
    # Ответ округлите до сотых.
    round(football[football.Wage < football.Wage.mean()].SprintSpeed.mean(), 2),


    # Какую позицию (Position) занимает футболист с самой высокой зарплатой (Wage)?
    football[football.Wage == football.Wage.max()].Position[0],


    # Сколько пенальти (Penalties) забили бразильские (Nationality, Brazil)
    # футболисты за период, данные о котором представлены в датасете?
    football[football.Nationality == 'Brazil'].Penalties.sum(),


    # Укажите средний возраст (Age) игроков, у которых точность
    # удара головой (HeadingAccuracy) > 50. Ответ округлите до сотых.
    round(football[football.HeadingAccuracy > 50].Age.mean(), 2),


    # Укажите возраст (Age) самого молодого игрока, у которого хладнокровие
    # (Composure) и реакция (Reactions) превышают 90% от максимального значения,
    # представленного в датасете.
    football[
        (football.Composure > football.Composure.max()*0.9)
        & (football.Reactions > football.Reactions.max()*0.9)
    ].Age.min(),


    # Определите, насколько средняя реакция (Reactions) самых взрослых игроков
    # (т.е. игроков, чей возраст (Age) равен максимальному) больше средней реакции
    # самых молодых игроков. Ответ округлите до сотых.
    round(
        football[
            football.Age == football.Age.max()
        ].Reactions.mean() - football[
            football.Age == football.Age.min()
        ].Reactions.mean(),

        2),


    # Из какой страны (Nationality) происходит больше всего игроков,
    # чья стоимость (Value) превышает среднее значение?
    football[football.Value > football.Value.mean()].Nationality.describe().top,
    #     football[football.Value > football.Value.mean()].Nationality.describe()['top'],
    #     football[football.Value > football.Value.mean()].Nationality.value_counts().index[0],


    # Определите, во сколько раз средняя зарплата (Wage) голкипера (Position, GK)
    # с максимальным значением показателя " Рефлексы" (GKReflexes) выше средней зарплаты
    # голкипера с максимальным значением показателя "Владение мячом" (GKHandling).
    # Ответ округлите до сотых.
    round(
        football[
            (football.Position == 'GK') & (football.GKReflexes == football.GKReflexes.max())
        ].Wage.mean() / football[
            (football.Position == 'GK') & (football.GKHandling == football.GKHandling.max())
        ].Wage.mean(),

        2),

    # Определите, во сколько раз средняя сила удара (ShotPower) самых агрессивных игроков
    # (игроков с максимальным значением показателя "Агрессивность" (Aggression)) выше средней
    # силы удара игроков с минимальной агрессией.
    # Ответ округлите до сотых.
    round(
        football[
            football.Aggression == football.Aggression.max()
        ].ShotPower.mean() / football[
            football.Aggression == football.Aggression.min()
        ].ShotPower.mean(),

        2),
)
# Out:
# 67.57
# 62.41
# 'RF'
# 22789
# 25.59
# 24
# 22.64
# 'Spain'
# 2.77
# 2.08
