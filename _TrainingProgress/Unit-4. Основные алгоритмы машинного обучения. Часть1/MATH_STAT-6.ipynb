# %% [markdown]
# # MATH&STAT-6. Статистика.

# %% [markdown]
# ## 9. Практика по доверительным интервалам

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
from scipy.stats import norm
import math

def confidence_interval_norm(alpha, sigma, n, mean):
    value = -norm.ppf(alpha / 2) * sigma / math.sqrt(n)
    return mean - value, mean + value

# %% [markdown]
# Снимок экрана 2021-04-14 в 09.12.08![image.png](attachment:image.png)

# %%
from scipy.stats import t
import math

def confidence_interval_t(alpha, s, n, mean):
    value = -t.ppf(alpha / 2, n - 1) * s / math.sqrt(n)
    return mean - value, mean + value

# %% [markdown]
# В обоих случаях:
#
#  - первый аргумент функции — уровень значимости ;
#  - второй — выборочное отклонение  или  ;
#  - третий — размер выборки ;
#  - четвертый — среднее значение выборки.

# %% [markdown]
# ## 10. Доверительный интервал для пропорции

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
